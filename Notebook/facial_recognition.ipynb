# %%
#import library
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#read a image
img=cv2.imread('E:/Abdul Qyum/Qyum.png')
print(img)
#plt.imshow(img)
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(img)
# Out:
# [[[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [244 253 246]
#   [249 253 252]
#   [249 251 252]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [246 252 247]
#   [250 253 251]
#   [250 251 250]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [246 252 247]
#   [250 253 251]
#   [250 251 250]]
#
#  ...
#
#  [[ 75  95 151]
#   [ 78  98 154]
#   [ 79  99 155]
#   ...
#   [146 166 223]
#   [145 165 222]
#   [146 166 223]]
#
#  [[ 78  97 154]
#   [ 80 100 156]
#   [ 81 101 158]
#   ...
#   [146 166 223]
#   [145 165 222]
#   [150 170 227]]
#
#  [[ 79  99 155]
#   [ 80 100 156]
#   [ 81 101 157]
#   ...
#   [145 165 222]
#   [147 167 224]
#   [148 168 225]]]

# %%
print(img)
# Out:
# [[254 254 254 ... 250 252 251]
#  [254 254 254 ... 250 252 251]
#  [254 254 254 ... 250 252 251]
#  ...
#  [109 112 113 ... 181 180 181]
#  [112 114 116 ... 181 180 185]
#  [113 114 115 ... 180 182 183]]

# %%
img=cv2.resize(img,(380,380))
plt.imshow(img)

# %%
#create haar cascade
cascade=cv2.CascadeClassifier('E:/python/haarcascade_frontalface_default.XML')

# %%
#now detect faces from image.

faces=cascade.detectMultiScale(
                          img,
                          scaleFactor=1.1,
                          minSize=(30,30),
                          flags=cv2.CASCADE_SCALE_IMAGE
                           )

# %%
print('found {} faces'.format(len(faces)))
# Out:
# found 1 faces

# %%
#draw a rectangle
for (x,y,w,h) in faces:
    print(x,y,w,h)
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),2)
# Out:
# 112 46 129 129

# %%
plt.imshow(img)
